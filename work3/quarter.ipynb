# %%
from pop import AI, Pilot
import numpy as np
import cv2

# %%
IMG_AMOUNT = 28

X_data = []
Y_data = []

for i in range(IMG_AMOUNT):
    img = cv2.imread('../../test_img/'+str(i)+'.jpg')
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img = cv2.resize(img, (50, 50), interpolation = cv2.INTER_AREA)
    X_data.append(img.reshape(50, 50, 1).astype(float))
    y = np.loadtxt('../../test_img/' + str(i) + '.txt')
    Y_data.append(y)

# %%
CNN = AI.CNN(input_size = [50,50], output_size = 2)
CNN.X_data = X_data
CNN.Y_data = Y_data

CNN.train(times = 500)
# Out:
# 10 step loss: 146446.203125
# 20 step loss: 64539.10546875
# 30 step loss: 84956.3125
# 40 step loss: 18278.96875
# 50 step loss: 4612.7158203125
# 60 step loss: 3925.222412109375
# 70 step loss: 1370.4373779296875
# 80 step loss: 169.33737182617188
# 90 step loss: 116.48941802978516
# 100 step loss: 96.29207611083984
# 110 step loss: 83.5050048828125
# 120 step loss: 141.14627075195312
# 130 step loss: 6.880909442901611
# 140 step loss: 78.13744354248047
# 150 step loss: 59.519622802734375
# 160 step loss: 112.2747802734375
# 170 step loss: 20.319772720336914
# 180 step loss: 62.983882904052734
# 190 step loss: 67.12736511230469
# 200 step loss: 71.07747650146484
# 210 step loss: 34.00476837158203
# 220 step loss: 5.426260948181152
# 230 step loss: 47.571311950683594
# 240 step loss: 84.6120376586914
# 250 step loss: 60.14949417114258
# 260 step loss: 15.519508361816406
# 270 step loss: 7.829886436462402
# 280 step loss: 31.119821548461914
# 290 step loss: 0.0
# ...

# %%
CNN.run([CNN.X_data[20]])
# Out:
# array([[0., 1.]], dtype=float32)

# %%
CNN.run([CNN.X_data[7]])
# Out:
# array([[1., 0.]], dtype=float32)

# %%
CNN.run([CNN.X_data[9]])
# Out:
# array([[1., 0.]], dtype=float32)

# %%
CNN.run([CNN.X_data[3]])
# Out:
# array([[1., 0.]], dtype=float32)

# %%
cam = Pilot.Camera()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pop/__init__.py in __init__(self, *args, **kwargs)
#    2659             if not re:
# -> 2660                 raise RuntimeError('Could not read image from camera.')
#    2661
#
# RuntimeError: Could not read image from camera.
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-29-d43c057dd23f> in <module>
# ----> 1 cam = Pilot.Camera()
#
# /usr/local/lib/python3.6/dist-packages/pop/__init__.py in __init__(self, width, height, auto_load)
#    2709
#    2710         if auto_load:
# -> 2711             self.load()
#    2712
#    2713     def __call__(self):
#
# /usr/local/lib/python3.6/dist-packages/pop/__init__.py in load(self)
#    2717     def load(self):
# ...

# %%
frame = cam.value  # 카메라에서 프레임 읽기

# 프레임을 그레이스케일로 변환
frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)  # 이미지를 그레이스케일로 변환

# 프레임 크기 조정
frame = cv2.resize(frame, (50, 50), interpolation=cv2.INTER_AREA)  # 이미지 크기 조정

# CNN 모델에 프레임 입력
CNN.run([frame.reshape(50, 50, 1)])  # CNN에 입력을 위한 형태 변경
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-99201f9611e6> in <module>
# ----> 1 frame = cam.value  # 카메라에서 프레임 읽기
#       2
#       3 # 프레임을 그레이스케일로 변환
#       4 frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)  # 이미지를 그레이스케일로 변환
#       5
#
# NameError: name 'cam' is not defined
